# %%
from workshop_utils import *
# %matplotlib inline

# %%
df = load_dataframe_from_s3('https://us-east-2.console.aws.amazon.com/athena/query/results/412cb09c-eb4d-4986-beca-2641e05ce8a6/csv')
# Out:
# Query results saved to:
# data/412cb09c-eb4d-4986-beca-2641e05ce8a6.csv

# %%
df = pd.read_csv('data/412cb09c-eb4d-4986-beca-2641e05ce8a6.csv')

# %%
df.set_index('user', inplace=True)
df.first_edit = df.first_edit.apply(pd.Timestamp)
df.last_edit = df.last_edit.apply(pd.Timestamp)

# %%
# Easier date objects?
df['first_day'] = df.first_edit.apply(lambda x: x.date())
df.head(2)
# Out:
#                         first_edit           last_edit  total_edits  \
# user
# Wildwater      2018-05-28 11:21:28 2019-08-18 16:28:35       355588
# maher_elgammal 2019-05-14 13:41:14 2019-08-08 16:05:45       117166
#
#                  first_day
# user
# Wildwater       2018-05-28
# maher_elgammal  2019-05-14

# %%
ax = df.groupby('first_day').aggregate('count')['first_edit'].plot(figsize=(15,8))
ax.set_xlabel("Date"); 
ax.set_ylabel("Number of mappers with their first edit", fontsize=16)
ax.set_title("How many users started mapping each day?", fontsize=16)
ax.get_figure().savefig('new_mappers_per_day_smooth.png', dpi=300)

# %%
ax = df.groupby('first_day').aggregate('count')['first_edit'].cumsum().plot(figsize=(15,8))
ax.set_xlabel("Date"); 
ax.set_ylabel("Number of mappers with their first edit", fontsize=16)
ax.set_title("How many users started mapping each day?", fontsize=16)
# Out:
# Text(0.5,1,'How many users started mapping each day?')

# %%
df.groupby('first_day').aggregate('count').sort_values(by='first_edit',ascending=False)
# Out:
#             first_edit  last_edit  total_edits
# first_day
# 2017-01-26        2822       2822         2822
# 2017-01-27        2528       2528         2528
# 2017-01-25        2176       2176         2176
# 2017-01-24        2146       2146         2146
# 2017-12-01        1709       1709         1709
# 2016-12-23        1698       1698         1698
# 2017-08-21        1449       1449         1449
# 2018-11-14        1424       1424         1424
# 2017-11-15        1379       1379         1379
# 2017-01-31        1342       1342         1342
# 2016-04-06        1284       1284         1284
# 2019-04-03        1266       1266         1266
# 2017-12-02        1257       1257         1257
# 2017-01-28        1256       1256         1256
# 2017-04-14        1216       1216         1216
# 2016-11-14        1210       1210         1210
# 2017-04-13        1204       1204         1204
# 2018-12-05        1190       1190         1190
# 2017-02-02        1187       1187         1187
# 2017-01-30        1183       1183         1183
# 2015-04-29        1180       1180         1180
# 2017-09-29        1154       1154         1154
# 2017-03-09        1129       1129         1129
# 2016-11-17        1122       1122         1122
# 2017-01-29        1120       1120         1120
# 2016-10-13        1115       1115         1115
# 2018-08-10        1105       1105         1105
# 2017-12-05        1092       1092         1092
# 2016-12-22        1083       1083         1083
# 2016-06-23        1078       1078         1078
# ...                ...        ...          ...
# 2007-01-25           1          1            1
# 2006-04-06           1          1            1
# 2006-04-02           1          1            1
# 2006-04-01           1          1            1
# 2006-05-13           1          1            1
# 2006-05-15           1          1            1
# 2006-06-25           1          1            1
# 2007-01-07           1          1            1
# 2006-12-23           1          1            1
# 2006-06-23           1          1            1
# 2006-06-17           1          1            1
# 2006-06-15           1          1            1
# 2006-06-14           1          1            1
# 2006-06-13           1          1            1
# 2006-06-11           1          1            1
# 2006-06-10           1          1            1
# 2006-06-09           1          1            1
# 2006-06-08           1          1            1
# 2006-06-07           1          1            1
# 2006-06-06           1          1            1
# 2006-06-04           1          1            1
# 2006-12-27           1          1            1
# 2006-05-29           1          1            1
# 2006-05-27           1          1            1
# 2006-12-31           1          1            1
# 2006-05-24           1          1            1
# 2007-01-03           1          1            1
# 2006-05-20           1          1            1
# 2006-05-19           1          1            1
# 2005-04-09           1          1            1
#
# [4902 rows x 3 columns]

# %%
df['lifespan'] = df.last_edit - df.first_edit

# %%
df[df.first_day==pd.Timestamp('2017-01-26').date()]['lifespan'].apply(lambda x: x.seconds).plot(kind='hist')
